# %% [markdown]
# <a href="https://colab.research.google.com/github/cawiya/SG1.3_Projects/blob/master/mod8_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
movies_df = pd.read_csv("/content/drive/MyDrive/movies.csv")
movies_df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
#check for missing values
movies_df.isnull().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %%
#filling the empty rows of the ratings column with mean value of the entire column

d = movies_df['RATING'].mean()
rating =movies_df['RATING'].fillna(d, inplace=True)

movies_df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %%
##filling the empty rows of the votes column zero mean value of the entire column
votes =movies_df['VOTES'].fillna(0, inplace=True)

movies_df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %%
#filling the empty rows of the runtime column with mean value of the entire column
b = movies_df['RunTime'].mean()
votes =movies_df['RunTime'].fillna(b, inplace=True)

movies_df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %%
#filling the empty rows of the gross column with mean value of the entire column
votes =movies_df['Gross'].fillna(0, inplace=True)

movies_df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %%
#checking for columns with no values
movies_df.isnull().sum()
# Out:
# MOVIES        0
# YEAR        644
# GENRE        80
# RATING        0
# ONE-LINE      0
# STARS         0
# VOTES         0
# RunTime       0
# Gross         0
# dtype: int64

# %%
#heatmap to check for missing values
sns.heatmap(movies_df.isnull(), yticklabels=False, annot=True)

# %%
# scan data for duplicates
movies_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994     True
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Length: 9999, dtype: bool

# %%
#number of duplicated rows
movies_df.duplicated().sum()
# Out:
# 431

# %%
#remove duplicated values
movies_df.drop_duplicates(inplace= True)

# %%
#recheck duplicated values
movies_df.duplicated().sum()
# Out:
# 0

# %%
#check the datatype for each columns
movies_df.dtypes
# Out:
# MOVIES       object
# YEAR         object
# GENRE        object
# RATING      float64
# ONE-LINE     object
# STARS        object
# VOTES        object
# RunTime     float64
# Gross        object
# dtype: object

# %%
#Remove rows with missing values to prepare data for visualization
movies_df.dropna( inplace = True)
movies_df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9993                            Totenfrau     (2022– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE    RATING  \
# 0         \nAction, Horror, Thriller              6.100000
# 1     \nAnimation, Action, Adventure              5.000000
# 2          \nDrama, Horror, Thriller              8.200000
# 3     \nAnimation, Adventure, Comedy              9.200000
# ...

# %%
#Rechecking for missing values
my_values = movies_df.isnull().sum()
print(my_values)
print('Dataset ready for visualization')
# Out:
# MOVIES      0
# YEAR        0
# GENRE       0
# RATING      0
# ONE-LINE    0
# STARS       0
# VOTES       0
# RunTime     0
# Gross       0
# dtype: int64
# Dataset ready for visualization
